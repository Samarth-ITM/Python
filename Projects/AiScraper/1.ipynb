# %% [markdown]
# # Intelligent Scrapper
#
# #### FLOW
# 1. Extract html
# 2. Parse HTML to AI
# 3. Provide in chunks(Later)
# 4. AI -> Filters Html Classes, ID, tags for Data extraction
# 5. Store the AI Output(Classes, ID, tags) and unpack
# 6. Parse the unpacked(Classes, ID, tags) values into the data extractor
# 7. Exrtract data, in parallel(async) in while True loops, for live changes,
# 8. Select important data to keep track of and keep fetching
# 9. Store Data -> plot trends
# 10. Display
