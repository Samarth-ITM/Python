# %%
import pandas as pd
import requests

# %%
url = "https://en.wikipedia.org/wiki/Giant_panda"

f = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}).text

# %%
len(pd.read_html(f))
# Out:
# 93

# %%
pd.read_html(f)[1]
# Out:
#          0                                                  1  \
# 0  Ursidae  Giant panda (Ailuropoda melanoleuca) Spectacle...
# 1      NaN  Giant panda (Ailuropoda melanoleuca) Spectacle...
# 2      NaN               Giant panda (Ailuropoda melanoleuca)
# 3      NaN  Spectacled bear (Tremarctos ornatus) Ursinae (...
# 4      NaN  Spectacled bear (Tremarctos ornatus) Ursinae (...
# 5      NaN               Spectacled bear (Tremarctos ornatus)
# 6      NaN  Ursinae (black, brown, sloth, sun, and polar b...
# 7      NaN  Ursinae (black, brown, sloth, sun, and polar b...
# 8      NaN                                                NaN
# 9      NaN                                                NaN
#
#                                       2
# 0                                   NaN
# 1  Giant panda (Ailuropoda melanoleuca)
# 2                                   NaN
# 3                                   NaN
# 4  Spectacled bear (Tremarctos ornatus)
# ...
